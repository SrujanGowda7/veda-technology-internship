# %%
import pandas as pd

print("Pandas imported successfully!")

# %%
student_data = {
    "Name": ["Srujan", "Rahul", "Ananya", "Priya", "Kiran"],
    "Age": [22, 21, 22, 20, 23],
    "Marks": [85, 78, 92, 88, 75],
    "Department": ["ISE", "CSE", "ISE", "ECE", "CSE"]
}

student_df = pd.DataFrame(student_data)

student_df

# %%
from sklearn.datasets import load_iris

iris = load_iris()

iris_df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

iris_df["species"] = [
    iris.target_names[i] for i in iris.target
]

iris_df.head()

# %%
print("First 5 rows:")
iris_df.head()

# %%
print("Shape of dataset:", iris_df.shape)

# %%
print("Columns:")
print(iris_df.columns.tolist())

# %%
print("Data Types:")
print(iris_df.dtypes)

# %%
print("Dataset Information:")
iris_df.info()

# %%
print("Summary Statistics:")
iris_df.describe()

# %%
print("Number of rows:", iris_df.shape[0])
print("Number of columns:", iris_df.shape[1])
print("Total elements:", iris_df.size)

# %% [markdown]
# ## Observations
#
# The Iris dataset contains 150 rows and 5 columns.
#
# The dataset contains four numerical features and one categorical species column.
#
# The `head()` function was used to view the first few records.
#
# The `info()` function was used to inspect the structure, non-null values, and data types.
#
# The `describe()` function was used to obtain summary statistics for numerical variables.
#
# The DataFrame was also explored using `shape`, `columns`, `dtypes`, and `size`.

# %% [markdown]
# ## Interview Questions
#
# ### 1. What is a Pandas DataFrame?
#
# A Pandas DataFrame is a two-dimensional labeled data structure in Python. It stores data in rows and columns, similar to a table or spreadsheet.
#
# ### 2. What information does `info()` provide?
#
# The `info()` function provides information about the DataFrame structure, including the number of rows, column names, non-null values, data types, and memory usage.
#
# ### 3. What is the difference between `shape` and `size`?
#
# `shape` returns the number of rows and columns in a DataFrame.
#
# For example:
#
# `(150, 5)` means 150 rows and 5 columns.
#
# `size` returns the total number of elements in the DataFrame.
#
# For a DataFrame with 150 rows and 5 columns:
#
# `150 × 5 = 750` elements.
